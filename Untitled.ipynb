# %%
import pandas as pd

# %%
file = "housing_data.csv"

# %%
df = pd.read_csv(file)
df.head()
# Out:
#    period_begin  period_end  period_duration region_type  region_type_id  \
# 0    2012-03-01  2012-03-31               30       state               4
# 1    2012-09-01  2012-09-30               30       state               4
# 2    2017-01-01  2017-01-31               30       state               4
# 3    2021-10-01  2021-10-31               30       state               4
# 4    2021-01-01  2021-01-31               30       state               4
#
#    table_id is_seasonally_adjusted      region  city       state  ...  \
# 0        21                      f     Georgia   NaN     Georgia  ...
# 1        49                      f   Minnesota   NaN   Minnesota  ...
# 2         9                      f  California   NaN  California  ...
# 3        41                      f       Maine   NaN       Maine  ...
# 4        27                      f       Idaho   NaN       Idaho  ...
#
#   sold_above_list_yoy price_drops  price_drops_mom  price_drops_yoy  \
# ...
